# %%
import numpy as np
import pandas as pd

# %%
o=pd.read_csv(r"/Users/faddy/Downloads/cleaned_all_phones.csv" )

# %%
o
# Out:
#             phone_name   brand           os  inches resolution  battery  \
# 0         Y6II Compact  Huawei  Android 5.1    5.00   720x1280     2200
# 1             K20 plus      LG  Android 7.0    5.30   720x1280     2700
# 2       P8 Lite (2017)  Huawei  Android 7.0    5.20  1080x1920     3000
# 3         Redmi Note 4  Xiaomi  Android 6.0    5.50  1080x1920     4100
# 4                  P10  Huawei  Android 7.0    5.10  1080x1920     3200
# ...                ...     ...          ...     ...        ...      ...
# 1507         vivo Y77t    Vivo   Android 13    6.64  1080x2388     5000
# 1508               11x  Realme   Android 13    6.72  1080x2400     5000
# 1509               GT5  Realme   Android 13    6.74  1240x2772     5240
# 1510          GT5 240W  Realme   Android 13    6.74  1240x2772     4600
# 1511  vivo iQOO Z7 Pro    Vivo   Android 13    6.78  1080x2400     4600
#
#      battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# ...

# %%
o.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1512 entries, 0 to 1511
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   phone_name         1512 non-null   object
#  1   brand              1512 non-null   object
#  2   os                 1512 non-null   object
#  3   inches             1512 non-null   float64
#  4   resolution         1512 non-null   object
#  5   battery            1512 non-null   int64
#  6   battery_type       1512 non-null   object
#  7   ram(GB)            1512 non-null   int64
#  8   announcement_date  1512 non-null   object
#  9   weight(g)          1512 non-null   float64
#  10  storage(GB)        1512 non-null   int64
#  11  video_720p         1512 non-null   bool
#  12  video_1080p        1512 non-null   bool
#  13  video_4K           1512 non-null   bool
#  14  video_8K           1512 non-null   bool
#  15  video_30fps        1512 non-null   bool
# ...

# %%
o.describe()
# Out:
#             inches      battery      ram(GB)    weight(g)  storage(GB)  \
# count  1512.000000  1512.000000  1512.000000  1512.000000  1512.000000
# mean      6.422460  4389.798942     6.683862   187.636243   109.164683
# std       0.477043   784.607022     2.701433    26.200115    74.436484
# min       3.800000  1821.000000     1.000000   130.000000     1.000000
# 25%       6.300000  4000.000000     4.000000   175.000000    64.000000
# 50%       6.500000  4500.000000     8.000000   187.000000   128.000000
# 75%       6.670000  5000.000000     8.000000   197.250000   128.000000
# max      10.400000  7250.000000    24.000000   500.000000   512.000000
#
#         price(USD)
# count  1512.000000
# mean    337.847036
# std     266.740821
# min      40.000000
# 25%     179.997500
# 50%     260.000000
# 75%     400.000000
# max    2300.000000

# %%
##how many unique mobile brands are there?
len(o["brand"].unique())
## there are 13 unique mobile brands.
# Out:
# 13

# %%
## Avg ram
o["ram(GB)"].mean()
## average ram of totsl phones is 6.6
# Out:
# 6.6838624338624335

# %%
##which phone name is having the maximum battery?
o.loc[o["battery"]==max(o["battery"])]
## V6 cellphone if honor brand is having the maximum battery capacity of 7250.
# Out:
#     phone_name  brand          os  inches resolution  battery battery_type  \
# 573         V6  Honor  Android 10    10.4  1200x2000     7250        Li-Po
#
#      ram(GB) announcement_date  weight(g)  ...  video_1080p  video_4K  \
# 573        8        2020-05-19      480.0  ...         True     False
#
#      video_8K  video_30fps  video_60fps  video_120fps  video_240fps  \
# 573     False         True        False         False         False
#
#      video_480fps  video_960fps  price(USD)
# 573         False         False       280.0
#
# [1 rows x 22 columns]

# %%
##which phpne is having minimum battery?
o.loc[o["battery"]==min(o["battery"])]
## iphone8 and iphone se(2020) of brand Apple are having the least battery capacity off all.
# Out:
#            phone_name  brand      os  inches resolution  battery battery_type  \
# 62           iPhone 8  Apple  iOS 11     4.7   750x1334     1821       Li-Ion
# 536  iPhone SE (2020)  Apple  iOS 13     4.7   750x1334     1821       Li-Ion
#
#      ram(GB) announcement_date  weight(g)  ...  video_1080p  video_4K  \
# 62         2        2017-09-12      148.0  ...         True      True
# 536        3        2020-04-15      148.0  ...         True      True
#
#      video_8K  video_30fps  video_60fps  video_120fps  video_240fps  \
# 62      False         True         True          True          True
# 536     False         True         True          True          True
#
#      video_480fps  video_960fps  price(USD)
# 62          False         False       210.0
# 536         False         False       189.5
#
# [2 rows x 22 columns]

# %%
##maximum battery capacity of Huawei brand?
gb=o.groupby("brand")

# %%
gb.get_group("Huawei").max()
## The maximum battery capacity of huawei brand is 7000.
# Out:
# phone_name             nova Y91
# brand                    Huawei
# os                      EMUI 13
# inches                      8.0
# resolution             720x1600
# battery                    7000
# battery_type              Li-Po
# ram(GB)                      12
# announcement_date    2023-05-23
# weight(g)                 300.0
# storage(GB)                 512
# video_720p                 True
# video_1080p                True
# video_4K                   True
# video_8K                  False
# video_30fps                True
# video_60fps                True
# video_120fps               True
# video_240fps               True
# video_480fps               True
# video_960fps               True
# price(USD)               2300.0
# dtype: object

# %%
##which phone brand has the minimum ram?
o.loc[min(o["ram(GB)"]),"brand"]
## LG cellphone is having the minimum ram of all cellphones.
# Out:
# 'LG'

# %%
##what is oldest phone announcement date?
min(o["announcement_date"])
## the oldest cellphone was announced on 2016-09-10.
# Out:
# '2016-09-01'

# %%
##how many phones has android 7 as operating system?
len(o.loc[o["os"]=="Android 7.0"])
## 33 cellphones run android 7 as operating system
# Out:
# 33

# %%
##which brand least number of phones produced?
o["brand"].value_counts().idxmin()
## Google is the least produced cellphone brand
# Out:
# 'Google'
